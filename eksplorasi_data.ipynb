# %% [markdown]
# # Data Pipeline

# %% [markdown]
# #### Data ingestion

# %%
import pandas as pd

# %%
df = pd.read_csv('UNdata_literacy rate.csv', delimiter=',')

# %% [markdown]
# #### Eksplor Data

# %%
df.head(15)
# Out:
#    Reference Area  Time Period          Sex        Age group  \
# 0     Afghanistan         1979       Female  15-24 year olds
# 1     Afghanistan         2011       Female  15-24 year olds
# 2     Afghanistan         2015       Female  15-24 year olds
# 3     Afghanistan         1979         Male  15-24 year olds
# 4     Afghanistan         2011         Male  15-24 year olds
# 5     Afghanistan         2015         Male  15-24 year olds
# 6     Afghanistan         1979  All genders  15-24 year olds
# 7     Afghanistan         2011  All genders  15-24 year olds
# 8     Afghanistan         2015  All genders  15-24 year olds
# 9         Albania         2001  All genders  15-24 year olds
# 10        Albania         2008  All genders  15-24 year olds
# 11        Albania         2011  All genders  15-24 year olds
# 12        Albania         2001       Female  15-24 year olds
# 13        Albania         2008       Female  15-24 year olds
# 14        Albania         2011       Female  15-24 year olds
#
#    Units of measurement  Observation Value
# 0               Percent          11.142800
# 1               Percent          32.113223
# 2               Percent          46.105990
# 3               Percent          45.796020
# 4               Percent          61.879069
# 5               Percent          69.420520
# 6               Percent          30.066350
# 7               Percent          46.990051
# 8               Percent          58.154900
# 9               Percent          99.435150
# 10              Percent          98.831210
# 11              Percent          98.791190
# 12              Percent          99.498080
# 13              Percent          99.121320
# 14              Percent          98.856240

# %%
df.tail()
# Out:
#      Reference Area  Time Period     Sex        Age group  \
# 4005       Zimbabwe         1982    Male  15-24 year olds
# 4006       Zimbabwe         1992    Male  15-24 year olds
# 4007       Zimbabwe         2011    Male  15-24 year olds
# 4008       Zimbabwe         2015    Male  15-24 year olds
# 4009       Zimbabwe         2015  Female  15-24 year olds
#
#      Units of measurement  Observation Value
# 4005              Percent           93.82696
# 4006              Percent           96.54062
# 4007              Percent           89.59058
# 4008              Percent           89.96682
# 4009              Percent           93.50235

# %%
print(df.info())                                         # menampilkan type data dan jumlah Non null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010 entries, 0 to 4009
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Reference Area        4010 non-null   object
#  1   Time Period           4010 non-null   int64
#  2   Sex                   4010 non-null   object
#  3   Age group             4010 non-null   object
#  4   Units of measurement  4010 non-null   object
#  5   Observation Value     4010 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 188.1+ KB
# None

# %%
#menampilkan statistik deskriptif dengan format yang lebih terstuktur dan mudah dibaca(T=menukar baris menjadi kolom,dan kolom menjadi baris)
print("Summary Statistics:")
df.describe().T
# Out:
# Summary Statistics:
#                     count         mean        std         min          25%  \
# Time Period        4010.0  2002.961596  10.318646  1975.00000  1996.000000
# Observation Value  4010.0    86.778156  16.830429     6.66406    78.474035
#
#                           50%          75%     max
# Time Period        2005.00000  2012.000000  2015.0
# Observation Value    94.57494    98.883607   100.0

# %%
# cek missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Reference Area          0
# Time Period             0
# Sex                     0
# Age group               0
# Units of measurement    0
# Observation Value       0
# dtype: int64

# %% [markdown]
# Karna tidak terdapat nilai yang kosong, data duplikasi, atau data yang tidak relevan. maka, tidak di lakukan cleanig data. jadi, bisa di lakukan analisis data yang relevan untuk analisis yang lebih akurat.

# %% [markdown]
# #### Validasi Data

# %%
# !pip install -q "great-expectations==0.18.19"

# %%
# Membuat data context 
from great_expectations.data_context import FileDataContext

context = FileDataContext.create(project_root_dir='./')

# %%
# Give a name to a Datasource. This name must be unique between Datasources.
datasource_name = 'csv literacy rate data'
datasource = context.sources.add_pandas('UNdata_literacy rate.csv')

# Give a name to a data asset
asset_name = 'literacy rate'
path_to_data = r'C:\Users\auliya rizki\Hactiv8\project\UNdata_literacy rate.csv'
asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data)

# Build batch request
batch_request = asset.build_batch_request()
# Out:
# ---------------------------------------------------------------------------
# DataContextError                          Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Give a name to a Datasource. This name must be unique between Datasources.
#       2 datasource_name = 'csv literacy rate data'
# ----> 3 datasource = context.sources.add_pandas('UNdata_literacy rate.csv')
#       5 # Give a name to a data asset
#       6 asset_name = 'literacy rate'
#
# File c:\Users\auliya rizki\anaconda3\Lib\site-packages\great_expectations\datasource\fluent\sources.py:473, in _SourceFactories.create_add_crud_method.<locals>.add_datasource(name_or_datasource, **kwargs)
#     471 datasource._data_context = self._data_context
#     472 datasource.test_connection()
# --> 473 datasource = self._data_context._add_fluent_datasource(datasource)
#     475 return datasource
#
# File c:\Users\auliya rizki\anaconda3\Lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py:780, in AbstractDataContext._add_fluent_datasource(self, datasource, save_changes, **kwargs)
#     778 # We currently don't allow one to overwrite a datasource with this internal method
#     779 if datasource_name in self.datasources:
# --> 780     raise gx_exceptions.DataContextError(
#     781         f"Can not write the fluent datasource {datasource_name} because a datasource of that "
#     782         "name already exists in the data context."
#     783     )
#     785 if not datasource:
#     786     ds_type = _SourceFactories.type_lookup[kwargs["type"]]
#
# DataContextError: Can not write the fluent datasource UNdata_literacy rate.csv because a datasource of that name already exists in the data context.

# %%
# Creat an expectation suite
expectation_suite_name = 'expectation-literacy-rate-dataset'
context.add_or_update_expectation_suite(expectation_suite_name)

# Create a validator using above expectation suite
validator = context.get_validator(
    batch_request = batch_request,
    expectation_suite_name = expectation_suite_name
)

# Check the validator
validator.head()
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#   Reference Area  Time Period     Sex        Age group Units of measurement  \
# 0    Afghanistan         1979  Female  15-24 year olds              Percent
# 1    Afghanistan         2011  Female  15-24 year olds              Percent
# 2    Afghanistan         2015  Female  15-24 year olds              Percent
# 3    Afghanistan         1979    Male  15-24 year olds              Percent
# 4    Afghanistan         2011    Male  15-24 year olds              Percent
#
#    Observation Value
# 0          11.142800
# 1          32.113223
# 2          46.105990
# 3          45.796020
# 4          61.879069

# %% [markdown]
# #### Automasi Data Pipeline

# %%
import pandas as pd

def load_data(file_path: str) -> pd.DataFrame:
    """
    Fungsi untuk membaca data dari file dan mengembalikan Pandas DataFrame.

    Parameters:
        file_path (str): Path atau URL ke file dataset (CSV, Excel, dll).

    Returns:
        pd.DataFrame: Data yang telah dimuat dalam bentuk Pandas DataFrame.
    """
    try:
        # Membaca file menggunakan pandas
        data = pd.read_csv(file_path)  # Pastikan menggunakan parameter file_path
        print(f"Data berhasil dibaca dari: {file_path}")
        return data
    except Exception as e:
        print(f"Terjadi kesalahan saat membaca file: {e}")
        raise  # Melempar ulang exception agar bisa ditangani lebih lanjut

# Memanggil fungsi dengan path file yang sesuai
file_path = 'UNdata_literacy rate.csv'
load_data(file_path)  # Ini memanggil fungsi
# Out:
# Data berhasil dibaca dari: UNdata_literacy rate.csv
#      Reference Area  Time Period     Sex        Age group  \
# 0       Afghanistan         1979  Female  15-24 year olds
# 1       Afghanistan         2011  Female  15-24 year olds
# 2       Afghanistan         2015  Female  15-24 year olds
# 3       Afghanistan         1979    Male  15-24 year olds
# 4       Afghanistan         2011    Male  15-24 year olds
# ...             ...          ...     ...              ...
# 4005       Zimbabwe         1982    Male  15-24 year olds
# 4006       Zimbabwe         1992    Male  15-24 year olds
# 4007       Zimbabwe         2011    Male  15-24 year olds
# 4008       Zimbabwe         2015    Male  15-24 year olds
# 4009       Zimbabwe         2015  Female  15-24 year olds
#
#      Units of measurement  Observation Value
# 0                 Percent          11.142800
# 1                 Percent          32.113223
# 2                 Percent          46.105990
# 3                 Percent          45.796020
# 4                 Percent          61.879069
# ...                   ...                ...
# 4005              Percent          93.826960
# 4006              Percent          96.540620
# 4007              Percent          89.590580
# 4008              Percent          89.966820
# 4009              Percent          93.502350
#
# [4010 rows x 6 columns]

# %% [markdown]
# ##### Proses ETL ke Mongodb dengan membuat file 'transform.py' dan 'load.py' dengan terpisah

# %%
# Koneksi ke MongoDB
client = pymongo.MongoClient("mongodb+srv://auliarizkirumahhorbo:auliya@aul-p.fc96f.mongodb.net/")  # Ganti dengan URL MongoDB Anda
db = client["literacy_db"]  # Nama database
collection = db["literacy_data"]  # Nama koleksi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Koneksi ke MongoDB
# ----> 2 client = pymongo.MongoClient("mongodb+srv://auliarizkirumahhorbo:auliya@aul-p.fc96f.mongodb.net/")  # Ganti dengan URL MongoDB Anda
#       3 db = client["literacy_db"]  # Nama database
#       4 collection = db["literacy_data"]
#
# NameError: name 'pymongo' is not defined

# %% [markdown]
# ##### Membuat apache airflow untuk menjadwalkan dan memantau workflow
